# %%
# Import Modules
from sklearn.linear_model import LinearRegression
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Download Data
SYF = yf.download('SYF', start='2017-12-29', end='2020-01-01')
SYF['Date'] = SYF.index
SYF['Daily_Ret'] = SYF['Adj Close'].pct_change()
SYF.dropna(inplace=True)

SPY = yf.download('SPY', start='2017-12-29', end='2020-01-01')
SPY['Date'] = SPY.index
SPY['Daily_Ret'] = SPY['Adj Close'].pct_change()
SPY.dropna(inplace=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
# Visualise the returns
plt.figure(figsize=(10, 4))
plt.title("Scatterplot of the Returns of SYF and SPY")
plt.scatter(x=SYF['Date'], y=SYF['Daily_Ret'], label='SYF')
plt.scatter(x=SPY['Date'], y=SPY['Daily_Ret'], label='SPY')
plt.xlabel("Date")
plt.ylabel("Return")
plt.legend()
plt.show()
